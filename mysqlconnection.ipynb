# %%
pip install mysql-connector-python
# Out:
# ...
#   Using cached mysql_connector_python-9.2.0-cp312-cp312-win_amd64.whl.metadata (6.2 kB)
# ...
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.1 MB ? eta -:--:--
# ...

# %%
import mysql.connector

db=mysql.connector.connect(
    host="localhost",
    user="root",
    password="Darshu@230804"
)
print(db)

# %%
dbcursor=db.cursor()
dbcursor.execute("create database if not exists booklist")

# %%
dbcursor.execute("show databases")

# %%
for i in dbcursor:
    print(i)
# Out:
# ('assignment_schema',)
# ('booklist',)
# ('countries',)
# ('customer_orders',)
# ('employee',)
# ('hr',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sakila',)
# ('sys',)
# ('temp_schema',)
# ('world',)

# %%
#we can specify on which database we are working on 
import mysql.connector

db=mysql.connector.connect(
    host="localhost",
    user="root",
    password="Darshu@230804",
    database="booklist"
)
print(db)

# %%
dbcursor=db.cursor()
dbcursor.execute("create table if not exists booklist.bookdetail (rating int(20),book varchar(40),price decimal(16,2))" )
dbcursor.execute("show tables")

for i in dbcursor:
    print(i)
# Out:
# ('bookdetail',)

# %%
dbcursor.execute("insert into booklist.bookdetail values (100,'rich dad poor dad',500),(50,'abc',200)")
for i in dbcursor:
    print(i)
db.commit()

# %%
form ="insert into bookdetail(rating,book,price) values(%s,%s,%s)"
data =[(4,"power of subconscious mind",99),
       (3,"attitude is everything",50),
       (3,"rich dad ",149)]
dbcursor.executemany(form,data)
db.commit()

# %%
dbcursor=db.cursor()
dbcursor.execute("select * from bookdetail")
result=dbcursor.fetchall()
for i in result:
    print(i)
# Out:
# (100, 'rich dad poor dad', Decimal('500.00'))
# (50, 'abc', Decimal('200.00'))
# (4, 'power of subconscious mind', Decimal('99.00'))
# (3, 'attitude is everything', Decimal('50.00'))
# (3, 'rich dad ', Decimal('149.00'))
