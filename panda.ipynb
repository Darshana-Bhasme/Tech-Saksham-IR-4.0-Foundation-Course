# %%
 # panda- (panel data)

# %%
import pandas as pd
import numpy as np

# %%
# numpy
"""
2-scalar
[1,2,3]-vector
[[1,2],[3,4]]-matrix
"""

# %%
# pandas
"""
1d-series-homogeneous array,size-immutable
2d- dataframe-hetrogeneous typed columns,size-mutable
"""

# %%
# series-array like
# dataframe- tabular format

# %%
# syntax of series
# pandas.series(data,index,dtype) dtype,index are optional

# %%
series= pd.Series([1,2,3,4,5])
print(series)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
series1=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(series1)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
for i in series:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# creating series using numpy

series2=pd.Series(np.random.randn(5), # it will take negative number also 
                  index=['a','b','c','d','e'])
print(series2)
# Out:
# a    2.255255
# b    1.131128
# c    0.426331
# d    0.891919
# e    1.224799
# dtype: float64

# %%
# series2=pd.Series(np.random.randint(5), # it will take positive value only 0 to 1
                  index=['a','b','c','d','e'])
# print(series2)
# Out:
# a    3
# b    3
# c    3
# d    3
# e    3
# dtype: int64

# %%
# creating series using dictionary

# %%
dictionary={'a':1,'b':2,'c':3}
d1=pd.Series(dictionary)
print(d1)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
# []- output will be in series
# [[]]-  output will be in dataframe

# %%
d1[[1,2]]
 # d1.iloc[[1,2]] # iloc-index used for featching data loc- only data have to fetch
# Out:
# C:\Users\daras\AppData\Local\Temp\ipykernel_23340\3590442367.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   d1[[1,2]]
# b    2
# c    3
# dtype: int64

# %%
d1.iloc[[1,2]]
# Out:
# b    2
# c    3
# dtype: int64

# %%
series1 + series2
# Out:
# a    3.255255
# b    3.131128
# c    3.426331
# d    4.891919
# e    6.224799
# dtype: float64

# %%
series + series1
# Out:
# a     2
# b     4
# c     6
# d     8
# e    10
# dtype: int64

# %%
# emptydataframe  
df=pd.DataFrame() # it will automatically create column and index 
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# how to add column,index and data to dataframe

df= pd.DataFrame(columns=['c1','c2','c3']) # only columns are updates 
print(df)
# Out:
# Empty DataFrame
# Columns: [c1, c2, c3]
# Index: []

# %%
df= pd.DataFrame(columns=['c1','c2','c3','c4'],
                index=range(1,6))
print(df)
# Out:
#     c1   c2   c3   c4
# 1  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN
# 5  NaN  NaN  NaN  NaN

# %%
 dictionary = {'a':1,'b':2,'c':3} # in series the a,b,c is used as index and here it is used as column
pd.DataFrame([dictionary])
# Out:
#    a  b  c
# 0  1  2  3

# %%
# attributes

df.index
# Out:
# RangeIndex(start=1, stop=6, step=1)

# %%
df.columns
# Out:
# Index(['c1', 'c2', 'c3', 'c4'], dtype='object')

# %%
# create a dataframe using list

mylist=[
    ['Apple','Red'],
    ['Banana','yellow'],
    ['Orange','orange']
]
mydata=pd.DataFrame(mylist)
mydata
# Out:
#         0       1
# 0   Apple     Red
# 1  Banana  yellow
# 2  Orange  orange

# %%
mydata=pd.DataFrame(mylist,columns=['Fruit_name','color']) # adding columns name into  existing Dataframe
mydata
# Out:
#   Fruit_name   color
# 0      Apple     Red
# 1     Banana  yellow
# 2     Orange  orange

# %%
#dataframe using numpy array

mylist1=np.array([
    [0,1],
    [2,3],
    [4,5]
])
mydf=pd.DataFrame(mylist1,columns=['Even','Odd'])
mydf
# Out:
#    Even  Odd
# 0     0    1
# 1     2    3
# 2     4    5

# %%
# load a csv  data using pandas
df= pd.read_csv('cereals.csv')
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df.set_index('name') #it will return a new Dataframe
# df.set_index('name',inplace=True) # it will modify the original
# Out:
#                            calories  protein  vitamins     rating
# name
# 100% Bran                        70        4        25  68.402973
# 100% Natural Bran               120        3         0  33.983679
# All-Bran                         70        4        25  59.425505
# All-Bran with Extra Fiber        50        4        25  93.704912
# Almond Delight                  110        2        25  34.384843
# Apple Cinnamon Cheerios         110        2        25  29.509541
# Apple Jacks                     110        2        25  33.174094
# Basic 4                         130        3        25  37.038562
# Bran Chex                        90        2        25  49.120253
# Bran Flakes                      90        3        25  53.313813

# %%
df.set_index('name',inplace=True) # it will modify the original  dataframe

# %%
df.head() # return 5 rows from beganing
# Out:
#                            calories  protein  vitamins     rating
# name
# 100% Bran                        70        4        25  68.402973
# 100% Natural Bran               120        3         0  33.983679
# All-Bran                         70        4        25  59.425505
# All-Bran with Extra Fiber        50        4        25  93.704912
# Almond Delight                  110        2        25  34.384843

# %%
df.tail()# return 5 rows from bottom
# Out:
#                          calories  protein  vitamins     rating
# name
# Apple Cinnamon Cheerios       110        2        25  29.509541
# Apple Jacks                   110        2        25  33.174094
# Basic 4                       130        3        25  37.038562
# Bran Chex                      90        2        25  49.120253
# Bran Flakes                    90        3        25  53.313813

# %%
df.describe() # return as many as you need by describing , automatically check and return only numerical columns
# Out:
#          calories    protein   vitamins     rating
# count   10.000000  10.000000  10.000000  10.000000
# mean    95.000000   2.900000  22.500000  49.205817
# std     25.495098   0.875595   7.905694  20.315297
# min     50.000000   2.000000   0.000000  29.509541
# 25%     75.000000   2.000000  25.000000  34.083970
# 50%    100.000000   3.000000  25.000000  43.079408
# 75%    110.000000   3.750000  25.000000  57.897582
# max    130.000000   4.000000  25.000000  93.704912

# %%
 # slicing rows using bracket operators

# %%
df=pd.read_csv('cereals.csv')
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df[1:4] # return from 1st column to 3rd column
# Out:
#                         name  calories  protein  vitamins     rating
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912

# %%
df['calories':'rating'] #cannot return give typeError

# %%
df['calories','rating'] #sing dimension are not allowed  to give multiple column names it give error

# %%
df[['calories','rating']]
# Out:
#    calories     rating
# 0        70  68.402973
# 1       120  33.983679
# 2        70  59.425505
# 3        50  93.704912
# 4       110  34.384843
# 5       110  29.509541
# 6       110  33.174094
# 7       130  37.038562
# 8        90  49.120253
# 9        90  53.313813

# %%
# boolean filter

# %%
df1=df[0:5]
boolean_list=[True,False,True,True,False]
df1[boolean_list]
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912

# %%
df['calories']>70 #return
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: calories, dtype: bool

# %%
condition=df['calories']>70
df[condition]
# Out:
#                       name  calories  protein  vitamins     rating
# 1        100% Natural Bran       120        3         0  33.983679
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %%
# filtering rows using &(and) and |(or) operators

# %%
df[(df['calories']>70) &(df['protein']<3)]
# Out:
#                       name  calories  protein  vitamins     rating
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 8                Bran Chex        90        2        25  49.120253

# %%
df[(df['calories']>70) |(df['protein']<3)]
# Out:
#                       name  calories  protein  vitamins     rating
# 1        100% Natural Bran       120        3         0  33.983679
# 4           Almond Delight       110        2        25  34.384843
# 5  Apple Cinnamon Cheerios       110        2        25  29.509541
# 6              Apple Jacks       110        2        25  33.174094
# 7                  Basic 4       130        3        25  37.038562
# 8                Bran Chex        90        2        25  49.120253
# 9              Bran Flakes        90        3        25  53.313813

# %%
# filtering data using loc()

df.loc[2,'protein'] # return in series format
# Out:
# 4

# %%
df.loc[0:4,['protein','name']]
# Out:
#    protein                       name
# 0        4                  100% Bran
# 1        3          100% Natural Bran
# 2        4                   All-Bran
# 3        4  All-Bran with Extra Fiber
# 4        2             Almond Delight

# %%
df.loc[[5],['protein']]  #return in dataframe format
# Out:
#    protein
# 5        2

# %%
""" more than one cloumn will automatically be considered as dataframe so no need to specify in []"""
df.loc[0:4,'name':'protein']
# Out:
#                         name  calories  protein
# 0                  100% Bran        70        4
# 1          100% Natural Bran       120        3
# 2                   All-Bran        70        4
# 3  All-Bran with Extra Fiber        50        4
# 4             Almond Delight       110        2

# %%
df[0:5]
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843

# %%
# slicing using iloc()

# %%
df.iloc[0:5,0:3] # 1st represent row 2nd represent column
# Out:
#                         name  calories  protein
# 0                  100% Bran        70        4
# 1          100% Natural Bran       120        3
# 2                   All-Bran        70        4
# 3  All-Bran with Extra Fiber        50        4
# 4             Almond Delight       110        2

# %%
# indixing and slicing

# %%
df.iloc[[0,2,4],0:3] # accessing the particular column using index numbers
# Out:
#              name  calories  protein
# 0       100% Bran        70        4
# 2        All-Bran        70        4
# 4  Almond Delight       110        2

# %%
# adding and deleting rows and columns

# %%
df1
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843

# %%
# it will update the original dataframe 
df1.loc[4]=['darshana',110,1,25,27.75]
df1
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                   darshana       110        1        25  27.750000

# %%
df # changes made in df1 will also affect df dataset it perofrm shallow copy
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                   darshana       110        1        25  27.750000
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
df1=df.iloc[0:5,].copy() # deep copy # copy is used to avoid the shallow copy it not change into the original dataframe 
df1
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                   darshana       110        1        25  27.750000

# %%
df1.drop(3,axis=0,inplace=True) #inplace - update into original dataframe if it is not give then it will create new dataframe and update into it
                                # axis=0 means rowwise axis=1 means columnwise

# %%
df1
# Out:
#                 name  calories  protein  vitamins     rating
# 0          100% Bran        70        4        25  68.402973
# 1  100% Natural Bran       120        3         0  33.983679
# 2           All-Bran        70        4        25  59.425505
# 4           darshana       110        1        25  27.750000

# %%
# to delete the column using column name.
df1.drop("name",axis=1)
# Out:
#    calories  protein  vitamins     rating
# 0        70        4        25  68.402973
# 1       120        3         0  33.983679
# 2        70        4        25  59.425505
# 3        50        4        25  93.704912
# 4       110        1        25  27.750000

# %%
# adding new column

# %%
df1['my new column']=[1,2,3,4,5]
df1
# Out:
#                         name  calories  protein  vitamins     rating  \
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                   darshana       110        1        25  27.750000
#
#    my new column
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5

# %%
# sorting values

# %%
ascending_df=df.sort_values(by= 'calories') # storing into the new dataframe
ascending_df
# Out:
#                         name  calories  protein  vitamins     rating
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813
# 4                   darshana       110        1        25  27.750000
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 1          100% Natural Bran       120        3         0  33.983679
# 7                    Basic 4       130        3        25  37.038562

# %%
desending_df=df.sort_values(by= 'calories',ascending=False) # storing into the new dataframe
desending_df
# Out:
#                         name  calories  protein  vitamins     rating
# 7                    Basic 4       130        3        25  37.038562
# 1          100% Natural Bran       120        3         0  33.983679
# 4                   darshana       110        1        25  27.750000
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813
# 0                  100% Bran        70        4        25  68.402973
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912

# %%
# changing the column name

# %%
df.columns
# Out:
# Index(['name', 'calories', 'protein', 'vitamins', 'rating'], dtype='object')

# %%
df.columns=['col1','col2','col3','col4','col5']

# %%
df
# Out:
#                         col1  col2  col3  col4       col5
# 0                  100% Bran    70     4    25  68.402973
# 1          100% Natural Bran   120     3     0  33.983679
# 2                   All-Bran    70     4    25  59.425505
# 3  All-Bran with Extra Fiber    50     4    25  93.704912
# 4                   darshana   110     1    25  27.750000
# 5    Apple Cinnamon Cheerios   110     2    25  29.509541
# 6                Apple Jacks   110     2    25  33.174094
# 7                    Basic 4   130     3    25  37.038562
# 8                  Bran Chex    90     2    25  49.120253
# 9                Bran Flakes    90     3    25  53.313813

# %%
# exporting and saving pandas dataframe

# %%
df.to_csv('myfiles.csv')

# %%
df.to_csv('myfiles.csv',index_label=False)

# %%
# concatenating dataframes

# %%
df1
# Out:
#                         name  calories  protein  vitamins     rating  \
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                   darshana       110        1        25  27.750000
#
#    my new column
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5

# %%
df2=df[5:8].copy()  # deep copy-copy  by value
df2
# Out:
#                       col1  col2  col3  col4       col5
# 5  Apple Cinnamon Cheerios   110     2    25  29.509541
# 6              Apple Jacks   110     2    25  33.174094
# 7                  Basic 4   130     3    25  37.038562

# %%
#if we try to combine df1 and df2 it will give error because column name is different

# %%
df2=df2.reset_index(drop=True) #reset_index for the rows it will create the index to same values of df1 and df2
df2
# Out:
#                       col1  col2  col3  col4       col5
# 0  Apple Cinnamon Cheerios   110     2    25  29.509541
# 1              Apple Jacks   110     2    25  33.174094
# 2                  Basic 4   130     3    25  37.038562

# %%
df1.drop("my new column",axis=1,inplace=True) # my new colum are dropping because it is present in the df1 and not in df2 so in concatination it will take null values for df2 so we dont need this
df1
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4                   darshana       110        1        25  27.750000

# %%
pd.concat([df,df1])
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# ...

# %%
pd.concat([df,df1], ignore_index=False) # ignore_index=False means it willignore the indexing it start by default values 0,1,2,3
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# ...

# %%
df=pd.read_csv('cereals.csv')
df
# Out:
#                         name  calories  protein  vitamins     rating
# 0                  100% Bran        70        4        25  68.402973
# 1          100% Natural Bran       120        3         0  33.983679
# 2                   All-Bran        70        4        25  59.425505
# 3  All-Bran with Extra Fiber        50        4        25  93.704912
# 4             Almond Delight       110        2        25  34.384843
# 5    Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                Apple Jacks       110        2        25  33.174094
# 7                    Basic 4       130        3        25  37.038562
# 8                  Bran Chex        90        2        25  49.120253
# 9                Bran Flakes        90        3        25  53.313813

# %%
pd.concat([df,df1], ignore_index=True)
# Out:
#                          name  calories  protein  vitamins     rating
# 0                   100% Bran        70        4        25  68.402973
# 1           100% Natural Bran       120        3         0  33.983679
# 2                    All-Bran        70        4        25  59.425505
# 3   All-Bran with Extra Fiber        50        4        25  93.704912
# 4              Almond Delight       110        2        25  34.384843
# 5     Apple Cinnamon Cheerios       110        2        25  29.509541
# 6                 Apple Jacks       110        2        25  33.174094
# 7                     Basic 4       130        3        25  37.038562
# 8                   Bran Chex        90        2        25  49.120253
# 9                 Bran Flakes        90        3        25  53.313813
# 10                  100% Bran        70        4        25  68.402973
# 11          100% Natural Bran       120        3         0  33.983679
# ...

# %%
# group by

data={'gender':['femal','male','female','male'],
      'score':[86,89,67,90]}

# new_df=pd.DataFrame.from_dict(data)
new_df=pd.DataFrame(data)
new_df
# Out:
#    gender  score
# 0   femal     86
# 1    male     89
# 2  female     67
# 3    male     90

# %%
group= new_df.groupby(new_df['gender']).mean()
group
# Out:
#         score
# gender
# femal    86.0
# female   67.0
# male     89.5

# %%
# missing values

# %%
from numpy import NaN

# %%
data1={'name':['person1','person2','person3','person4'],
       'age':[28,27,NaN,36]}
data1
# Out:
# {'name': ['person1', 'person2', 'person3', 'person4'],
#  'age': [28, 27, nan, 36]}

# %%
data=pd.DataFrame(data1)
data
# Out:
#       name   age
# 0  person1  28.0
# 1  person2  27.0
# 2  person3   NaN
# 3  person4  36.0

# %%
data.isnull() #if null retuen true
# Out:
#     name    age
# 0  False  False
# 1  False  False
# 2  False   True
# 3  False  False

# %%
data.isnull().sum() # it will return the total null values in the dataframe
# Out:
# name    0
# age     1
# dtype: int64

# %%
data.dropna()
#data.dropna(inplace=True)
# Out:
#       name   age
# 0  person1  28.0
# 1  person2  27.0
# 3  person4  36.0

# %%
data['age'].dtype
# Out:
# dtype('float64')

# %%
data2={'name':['person1','person2','person3','person4'],
       'age':[28,27,27,28]}

# %%
df=pd.DataFrame(data2)
df
# Out:
#       name  age
# 0  person1   28
# 1  person2   27
# 2  person3   27
# 3  person4   28

# %%
df['age'].dtype
# Out:
# dtype('int64')

# %%
data
# Out:
#       name        age
# 0  person1  28.000000
# 1  person2  27.000000
# 2  person3  30.333333
# 3  person4  36.000000

# %%
## filling missing values with mean/median/mode

# %%
df['age'].fillna(df['age'].mean()) # mean value is calculated
# Out:
# 0    28
# 1    27
# 2    27
# 3    28
# Name: age, dtype: int64

# %%
data['age'].fillna(data['age'].mean()) # mean-average value is calculated
# data['age'].fillna(data['age'].mean(),inplace=True)
# Out:
# 0    28.000000
# 1    27.000000
# 2    30.333333
# 3    36.000000
# Name: age, dtype: float64

# %%
df['age'].mode()[0] #which particular age is occuring the multiple times
# Out:
# 27

# %%
df['age'].mode()
# Out:
# 0    27
# 1    28
# Name: age, dtype: int64

# %%
data
# Out:
#       name        age
# 0  person1  28.000000
# 1  person2  27.000000
# 2  person3  30.333333
# 3  person4  36.000000

# %%
df['age'].fillna(df['age'].mode())
# Out:
# 0    28
# 1    27
# 2    27
# 3    28
# Name: age, dtype: int64

# %%
# using median
df['age'].fillna(df['age'].median())
# Out:
# 0    28
# 1    27
# 2    27
# 3    28
# Name: age, dtype: int64

# %%
# Histogram

# %%
# bar plot

# %%
values=[10,20,30]
plt.bar(values,[0.5,1,2,3],width=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 values=[10,20,30]
# ----> 2 plt.bar(values,[0.5,1,2,3],width=2)
#       3 plt.show()
#
# NameError: name 'plt' is not defined
